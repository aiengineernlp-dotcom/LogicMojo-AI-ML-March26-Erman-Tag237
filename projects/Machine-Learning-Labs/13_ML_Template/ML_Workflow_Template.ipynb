# %% [markdown]
# Import
#
# ↓
#
# Load Data
#
# ↓
#
# EDA
#
# ↓
#
# Cleaning
#
# ↓
#
# Split
#
# ↓
#
# Scaling
#
# ↓
#
# Model
#
# ↓
#
# Train
#
# ↓
#
# Prediction
#
# ↓
#
# Evaluation
#
# ↓
#
# Interpretation
#
# ↓
#
# Visualization
